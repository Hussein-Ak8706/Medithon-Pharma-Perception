# %%
from bs4 import BeautifulSoup
import requests

# %%
url = 'https://www.drugs.com/comments/codeine/'
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:147.0) Gecko/20100101 Firefox/147.0'}
result = requests.get(url, headers=headers)
print(result.content.decode())
# Out:
# <!DOCTYPE html>
# <html lang='en'>
#
# <head>
# 	<meta charset="utf-8">
# 	<title>Codeine Reviews &amp; Ratings - Drugs.com</title>
# 			<meta name="description" content="Reviews and ratings for Codeine. 72 reviews submitted with a 7.9 average score.">
# 			<meta name="viewport" content="width=device-width, initial-scale=1">
# 	<meta name="referrer" content="origin-when-cross-origin">
# 			<meta name="robots" content="max-image-preview:large">
# 		<link rel='canonical' href='https://www.drugs.com/comments/codeine/'>
# <link rel='search' type='application/opensearchdescription+xml' href='/opensearch.xml' title='Drugs.com'>
# <meta property="fb:app_id" content="1470988726468809">
# <meta property="article:author" content="https://www.facebook.com/Drugscom">
# <meta property="article:publisher" content="https://www.facebook.com/Drugscom">
# <meta property="og:title" content="Codeine Reviews &amp; Ratings - Drugs.com">
# <meta property="og:image" content="https://www.drugs.com/img/social/ddc-opengraph-logomark.png">
# <meta property="og:site_name" content="Drugs.com">
# <meta property="og:locale" content="en_US">
# <meta property="og:type" content="article">
# <meta property='og:description' content="Reviews and ratings for Codeine. 72 reviews submitted with a 7.9 average score.">
# <meta property='og:url' content="https://www.drugs.com/comments/codeine/">
# <!-- Twitter Summary Card -->
# <meta name="twitter:card" content="summary">
# <meta name="twitter:site" content="@drugscom">
# 		<link rel='preconnect' href='https://securepubads.g.doubleclick.net'>
# <link rel='preconnect' href='https://tpc.googlesyndication.com'>
# <link rel='preconnect' href='https://pagead2.googlesyndication.com'>
# <link rel='preconnect' href='https://fundingchoicesmessages.google.com'>
# <link rel='preconnect' href='https://micro.rubiconproject.com'>
# 	<!-- Favicons -->
# 	<link rel='manifest' href='/manifest.json'>
# 	<link rel='icon' type='image/png' sizes='32x32' href='/img/logo/favicon/ddc-icon-32x32.png'>
# 	<link rel='icon' type='image/png' sizes='16x16' href='/img/logo/favicon/ddc-icon-16x16.png'>
# 	<link rel='apple-touch-icon' sizes='180x180' href='/img/logo/favicon/apple-touch-icon-180x180.png'>
# 	<!-- CSS -->
# 	<style>body{margin:0;padding:0;}img{max-width:100%;height:auto;}.ddc-main-content{overflow-wrap:break-word;word-wrap:break-word;}.responsive-table-wrap{overflow-x:auto;}</style>
# 	<link rel='stylesheet' href='/bundle/css/ddc-pack-site.min.f9feb029.css'>
# 	<link rel='stylesheet' href='/bundle/css/component/component-tag.min.d24d3227.css'>
# <link rel='stylesheet' href='/bundle/css/component/component-paging.min.c79e3210.css'>
# <link rel='stylesheet' href='/bundle/css/section/ddc-section-related-docs.min.847fc865.css'>
# <link rel='stylesheet' href='/bundle/css/component/component-table-sortable.min.c0d9c385.css'>
# <link rel='stylesheet' href='/bundle/css/section/ddc-section-rating.min.2adc2401.css'>
# 		<link rel='stylesheet' href='/bundle/css/support/support-print.min.14b50b98.css' media='print'>
# 		<link rel='next' href='https://www.drugs.com/comments/codeine/?page=2'>
# 			<!-- Schema -->
# 	<script type='application/ld+json'>[{"@context":"https://schema.org/","@type":"BreadcrumbList","itemListElement":[{"@type":"ListItem","position":1,"name":"Home","item":{"@type":"MedicalWebPage","@id":"https://www.drugs.com/"}},{"@type":"ListItem","position":2,"name":"Codeine","item":{"@type":"MedicalWebPage","@id":"https://www.drugs.com/codeine.html"}},{"@type":"ListItem","position":3,"name":"Reviews","item":{"@type":"MedicalWebPage","@id":"https://www.drugs.com/comments/codeine/"}}]},{"@context":"https://schema.org/","@type":"MedicalWebPage","@id":"https://www.drugs.com/comments/codeine/","url":"https://www.drugs.com/comments/codeine/","name":"Codeine Reviews &amp; Ratings","description":"Reviews and ratings for Codeine. 72 reviews submitted with a 7.9 average score.","audience":{"@type":"MedicalAudience","audienceType":"Patient"},"author":{"@type":"Organization","name":"Drugs.com","url":"https://www.drugs.com"},"isPartOf":{"@type":"WebSite","@id":"https://www.drugs.com/#website","name":"Drugs.com","url":"https://www.drugs.com"},"publisher":{"@type":"Organization","@id":"https://www.drugs.com/#organization","name":"Drugs.com","url":"https://www.drugs.com","logo":{"@type":"ImageObject","url":"https://www.drugs.com/img/logo/schema/drugscom-logomark-112x112.png","width":112,"height":112}},"image":{"@type":"ImageObject","contentUrl":"https://www.drugs.com/images/pills/mtm/Codeine%20Sulfate%2030%20mg-ROX/codeine-sulfate-30-mg-54-783-1000.jpg","url":"https://www.drugs.com/images/pills/mtm/Codeine%20Sulfate%2030%20mg-ROX/codeine-sulfate-30-mg-54-783-1000.jpg","caption":"Codeine 30 mg"},"mainEntity":{"@type":"Drug","name":"codeine","nonProprietaryName":"codeine","pregnancyCategory":{"@type":"DrugPregnancyCategory","name":"C"},"pregnancyWarning":"Animal reproduction studies have shown an adverse effect on the fetus and there are no adequate and well-controlled studies in humans, but potential benefits may warrant use in pregnant women despite potential risks.","prescriptionStatus":"Prescription Only","aggregateRating":{"@type":"AggregateRating","url":"https://www.drugs.com/comments/codeine/","reviewCount":72,"ratingCount":72,"ratingValue":"7.9","bestRating":10,"worstRating":1},"image":{"@type":"ImageObject","contentUrl":"https://www.drugs.com/images/pills/mtm/Codeine%20Sulfate%2030%20mg-ROX/codeine-sulfate-30-mg-54-783-1000.jpg","url":"https://www.drugs.com/images/pills/mtm/Codeine%20Sulfate%2030%20mg-ROX/codeine-sulfate-30-mg-54-783-1000.jpg","caption":"Codeine 30 mg"}}}]</script>
# <script >bazadebezolkohpepadr="1894384037"</script><script type="text/javascript" src="https://www.drugs.com/akam/13/70ea034e"  defer></script></head>
#
# <body class='page-section-reviews page-doctype-content page-comments-codeine'>
#
#
# <a href='#content' class='ddc-skip-link'>Skip to main content</a>
#
#
# <header id="header" class="ddc-header">
# 	<div class="ddc-header-container ddc-width-container">
#
# 		<div class="ddc-header-logo">
# 			<a href="//www.drugs.com/">
# 				<img class='logo' src='/img/logo/drugscom-logo.svg' alt="Drugs.com - Go to homepage" width='280' height='58' loading='lazy'>
# 			</a>
# 		</div>
# 					<form action='/search.php' method='get' class='ddc-header-search' role='search'>
# 				<div class="ddc-input-group-action">
# 					<label>
# 						<span class="ddc-form-label-placeholder">Search Drugs.com</span>
# 						<input type="text" id="livesearch-main" class="livesearch webkit-speech" name="searchterm" value="" placeholder="Search" maxlength="70" data-required="1" data-value="codeine" data-autocomplete='main'>
# 					</label>
#
# 					<div class='ddc-header-search-close'>
# 						<button type='button' class='ddc-flex ddc-flex-items-center ddc-flex-justify-center' data-search-close>
# 							<span class="ddc-sr-only">Close</span>
# 							<svg class='ddc-icon ddc-icon-close' width='20' height='20' viewBox='0 0 24 24' aria-hidden='true' focusable='false' xmlns='http://www.w3.org/2000/svg'><path d='M18 7.05 16.95 6 12 10.95 7.05 6 6 7.05 10.95 12 6 16.95 7.05 18 12 13.05 16.95 18 18 16.95 13.05 12 18 7.05Z' /></svg>						</button>
# 					</div>
#
# 					<div class="ddc-header-search-filter">
# 						<button type='button' data-value="search-alias=aps">
# 							<span data-search-select-value>All</span>
# 							<svg class='ddc-icon ddc-icon-directiondown' width='20' height='20' viewBox='0 0 24 24' aria-hidden='true' focusable='false' xmlns='http://www.w3.org/2000/svg'><path d='M12 16.5 4.5 9l1.05-1.05L12 14.4l6.45-6.45L19.5 9 12 16.5Z' /></svg>						</button>
#
# 						<label>
# 							<span class="ddc-form-label-placeholder">Select the section you want to search in</span>
# 							<select name="sources[]" data-search-select>
# 								<option value=''>All</option>
# <option value='consumer'>Consumer</option>
# <option value='professional'>Professional</option>
# <option value='drugimages'>Pill ID</option>
# <option value='interactions'>Interactions</option>
# <option value='newsandalerts'>News and alerts</option>
# <option value='cg'>Care notes</option>
# <option value='natural'>Natural products</option>
# 							</select>
# 						</label>
# 					</div>
#
# 					<button type='submit' class='ddc-btn ddc-header-search-button'>
# 						<span class='ddc-sr-only'>Search</span>
# 						<svg class='ddc-icon ddc-icon-search' width='24' height='24' viewBox='0 0 24 24' aria-hidden='true' focusable='false' xmlns='http://www.w3.org/2000/svg'><path d='M17 15.4c2.4-3.1 2.4-7.4 0-10.5C14.1 1.1 8.7.4 4.9 3.3 1.1 6.2.4 11.6 3.3 15.4c2.9 3.8 8.3 4.5 12.1 1.6l4.8 4.8 1.6-1.6-4.8-4.8Zm-6.9 1.1c-3.5 0-6.4-2.9-6.4-6.4 0-3.5 2.9-6.4 6.4-6.4 3.5 0 6.4 2.9 6.4 6.4 0 3.5-2.9 6.4-6.4 6.4Z' /></svg>					</button>
# 				</div>
#
# 				<nav class="ddc-header-alpha-menu">
# 					Browse medications:
# 					<ul class="ddc-mg-0 ddc-list-unstyled">
# 						<li><a href='/alpha/a.html'>a</a></li>
# <li><a href='/alpha/b.html'>b</a></li>
# <li><a href='/alpha/c.html'>c</a></li>
# <li><a href='/alpha/d.html'>d</a></li>
# <li><a href='/alpha/e.html'>e</a></li>
# <li><a href='/alpha/f.html'>f</a></li>
# <li><a href='/alpha/g.html'>g</a></li>
# <li><a href='/alpha/h.html'>h</a></li>
# <li><a href='/alpha/i.html'>i</a></li>
# <li><a href='/alpha/j.html'>j</a></li>
# <li><a href='/alpha/k.html'>k</a></li>
# <li><a href='/alpha/l.html'>l</a></li>
# <li><a href='/alpha/m.html'>m</a></li>
# <li><a href='/alpha/n.html'>n</a></li>
# <li><a href='/alpha/o.html'>o</a></li>
# <li><a href='/alpha/p.html'>p</a></li>
# <li><a href='/alpha/q.html'>q</a></li>
# <li><a href='/alpha/r.html'>r</a></li>
# <li><a href='/alpha/s.html'>s</a></li>
# <li><a href='/alpha/t.html'>t</a></li>
# <li><a href='/alpha/u.html'>u</a></li>
# <li><a href='/alpha/v.html'>v</a></li>
# <li><a href='/alpha/w.html'>w</a></li>
# <li><a href='/alpha/x.html'>x</a></li>
# <li><a href='/alpha/y.html'>y</a></li>
# <li><a href='/alpha/z.html'>z</a></li>
# <li><a href='/alpha/0-9.html'>0-9</a></li>
# 					</ul>
#
# 					<a class='ddc-text-color-secondary' href="/search_advanced.html">Advanced Search</a>
# 				</nav>
# 			</form>
# 						<nav class='ddc-header-nav-account' aria-label="Account navigation">
# 									<a class='ddc-btn ddc-btn-empty ddc-btn-small ddc-btn-register' rel='nofollow' href='/account/register/'>Register</a>
# 					<a class='ddc-btn ddc-btn-secondary ddc-btn-small' rel='nofollow' href='/account/login/'>Sign in</a>
# 								</nav>
# 					<div class='ddc-header-nav-controls'>
# 			<button data-nav-toggle>
# 				<span class='ddc-sr-only'>Site navigation</span>
# 				<svg class='ddc-icon ddc-icon-menu' width='28' height='28' viewBox='0 0 24 24' aria-hidden='true' focusable='false' xmlns='http://www.w3.org/2000/svg'><path d='M22.5 7.125h-21v-2.25h21v2.25Zm0 6h-21v-2.25h21v2.25Zm-21 6h21v-2.25h-21v2.25Z' /></svg>				<svg class='ddc-icon ddc-icon-close' width='28' height='28' viewBox='0 0 24 24' aria-hidden='true' focusable='false' xmlns='http://www.w3.org/2000/svg'><path d='M18 7.05 16.95 6 12 10.95 7.05 6 6 7.05 10.95 12 6 16.95 7.05 18 12 13.05 16.95 18 18 16.95 13.05 12 18 7.05Z' /></svg>			</button>
# 		</div>
# 	</div>
#
# 	<div class='ddc-width-container'>
# 		<nav class='ddc-header-nav' aria-label="Main navigation">
# 		<ul>
#
# <li class='ddc-header-nav-item ddc-header-nav-item-plus'>
# 	<a href='/account/plan/?launch=ddc-tier-1'>
# 		<div class='ddc-flex ddc-flex-column ddc-flex-gap-1'>
# 			<b>Upgrade to a Plus Plan</b>
# 			<span class='ddc-display-block ddc-text-color-secondary ddc-text-size-small ddc-text-weight-normal'>Remove ads and unlock more features.</span>
# 		</div>
# 		<svg class='ddc-icon ddc-icon-plusexpressive' width='20' height='20' viewBox='0 0 24 24' aria-hidden='true' focusable='false' xmlns='http://www.w3.org/2000/svg'><path d='m15.583 16.804-1.72.297a1.04 1.04 0 0 0 0 2.048l1.73.298c.491.085.875.469.96.96l.279 1.616c.097.565.595.977 1.168.977s1.071-.412 1.168-.977l.28-1.616c.084-.491.468-.875.959-.96l1.73-.298a1.039 1.039 0 0 0 0-2.048l-1.72-.297a1.176 1.176 0 0 1-.962-.972l-.296-1.845a1.173 1.173 0 0 0-2.318 0l-.296 1.845c-.08.496-.466.887-.962.972ZM5.05 7.101l-2.67.46a1.662 1.662 0 0 0 0 3.277l2.688.463a2 2 0 0 1 1.63 1.631l.43 2.491a1.9 1.9 0 0 0 3.744 0l.43-2.49a2 2 0 0 1 1.63-1.632l2.688-.463a1.662 1.662 0 0 0 0-3.277l-2.67-.46a2 2 0 0 1-1.635-1.654l-.461-2.867a1.878 1.878 0 0 0-3.708 0l-.46 2.867A2 2 0 0 1 5.05 7.101Z' /></svg>	</a>
# </li>
# 					<li class='ddc-header-nav-item ddc-header-nav-item-account'>
# 				<div class='ddc-flex ddc-flex-gap-3 ddc-header-nav-account-actions'>
# 					<a class='ddc-btn ddc-btn' href='/account/register/' rel='nofollow'>Register</a>
# 					<a class='ddc-btn ddc-btn-secondary' href='/account/login/' rel='nofollow'>Sign in</a>
# 				</div>
# 			</li>
# 					<li class='ddc-header-nav-item'><a href='/drug_information.html'>Drugs A-Z</a></li>
# 		<li class='ddc-header-nav-item'><a href='/pill_identification.html'>Pill Identifier</a></li>
# 		<li class='ddc-header-nav-item'><a href='/drug_interactions.html'>Drug Interaction Checker</a></li>
# 		<li class='ddc-header-nav-item'><a href='/compare/'>Compare Drugs</a></li>
# 		<li class='ddc-header-nav-item'><a href='/news.html'>News</a></li>
# 		<li class='ddc-header-nav-item'><a href='/professionals.html'>Pro Edition</a></li>
# 		<li class='ddc-header-nav-item'><a class='ddc-link-forward' href='/sitemap.html'>More<span class='ddc-sr-only'> Resources</span></a></li>
# 		<li class='ddc-header-nav-item'><a href='/support/'>Help &amp; Support</a></li>
# 	</ul>
# </nav>
# 	</div>
# </header>
#
#
# <div class='display-ad-leaderboard'>
# <div id='display-ad-1' class='display-ad display-ad-static display-ad-728x90'></div>	<button type='button' data-toggle-class='.display-ad-leaderboard'>
# 		<span class='ddc-sr-only'>Close</span>
# 		<svg class='ddc-icon ddc-icon-close' width='20' height='20' viewBox='0 0 24 24' aria-hidden='true' focusable='false' xmlns='http://www.w3.org/2000/svg'><path d='M18 7.05 16.95 6 12 10.95 7.05 6 6 7.05 10.95 12 6 16.95 7.05 18 12 13.05 16.95 18 18 16.95 13.05 12 18 7.05Z' /></svg>	</button>
# </div>
#
# <main id='container' class='ddc-main-container ddc-width-container' data-ad-container>
# 	<div id='content' class='ddc-main-content' data-ad-injection>
#
# 		<div class='ddc-main-content-head'>
# <nav class='ddc-breadcrumb' aria-label='Breadcrumbs'>
# <ol class='ddc-breadcrumb-3'>
# <li><a class='ddc-breadcrumb-item' href='/'>Home</a></li>
# <li><a class='ddc-breadcrumb-item' href='/codeine.html'>Codeine</a></li>
# <li aria-current='page'><span class='ddc-breadcrumb-item'>Reviews</span></li>
# </ol>
# </nav>
# <div class='ddc-page-header-options ddc-flex ddc-flex-gap-3 noprint'>
# <button type='button' class='ddc-flex ddc-flex-items-center ddc-flex-gap-1' data-action='print'>
# <svg class='ddc-icon ddc-icon-print' width='16' height='16' viewBox='0 0 24 24' aria-hidden='true' focusable='false' xmlns='http://www.w3.org/2000/svg'><path d='M21 6.75h-2.25v-4.5H5.25v4.5H3a1.5 1.5 0 0 0-1.5 1.5v7.5a1.5 1.5 0 0 0 1.5 1.5h2.25v4.5h13.5v-4.5H21a1.5 1.5 0 0 0 1.5-1.5v-7.5a1.5 1.5 0 0 0-1.5-1.5Zm-14.25-3h10.5v3H6.75v-3Zm10.5 16.5H6.75v-7.5h10.5v7.5Zm3.75-4.5h-2.25v-4.5H5.25v4.5H3v-7.5h18v7.5Z' /></svg>Print
# </button>
# <button type='button' class='ddc-flex ddc-flex-items-center ddc-flex-gap-1' data-action='share-mednotes' data-source='header'>
# <svg class='ddc-icon ddc-icon-docsave' width='16' height='16' viewBox='0 0 24 24' aria-hidden='true' focusable='false' xmlns='http://www.w3.org/2000/svg'><path d='M4.5 4.5A1.5 1.5 0 0 1 6 3h12a1.5 1.5 0 0 1 1.5 1.5V12H18V4.5H6V21h6v1.5H6A1.5 1.5 0 0 1 4.5 21V4.5Zm18 13.5h-3v-3H18v3h-3v1.5h3v3h1.5v-3h3V18ZM8.25 6.75h7.5v1.5h-7.5v-1.5Zm7.5 3.75h-7.5V12h7.5v-1.5Zm-7.5 3.75H12v1.5H8.25v-1.5Z' /></svg>Save
# </button>
# </div>
# </div>
#
# <!-- Content start -->
#
#
# <h1>
# 			Codeine User Reviews &amp; Ratings
# 		</h1>
#
#
# 	<p>
# 					<a href='/codeine.html'>Codeine</a>
# 				has an average rating of <b>7.9</b> out of 10 from a total of <b>72 reviews</b>
# 					on Drugs.com.
# 				<b>71%</b> of reviewers reported a positive experience, while <b>15%</b> reported a negative experience.
# 	</p>
#
#
# 	<div class='responsive-table-wrap'>
# 		<table class='data-list ddc-table-sortable'>
# 			<thead>
# 			<tr>
# 									<th scope='col' class='sortable'>
# 						<a class='sortable-link' href='/comments/codeine/?sort=condition&amp;order=asc' rel='nofollow'>Condition</a>
# 					</th>
# 					<th scope='col' class='sortable' >
# 						<a class='sortable-link' href='/comments/codeine/?sort=rating&amp;order=desc' rel='nofollow'>Avg. Rating</a>
# 					</th>
# 					<th scope='col' class='sortable active desc'>
# 						<a class='sortable-link' href='/comments/codeine/?sort=reviews&amp;order=desc' rel='nofollow'>Reviews</a>
# 					</th>
# 								<th scope='col'>Compare</th>
# 			</tr>
# 			</thead>
# 												<tr>
# 						<th scope='row'>
# 							<span class='ddc-condition-label-wrap'>Pain </span>
# 						</th>
# 						<td>
# 							<div class='ddc-rating-summary'>
# 								<div>7.0</div>
# 															</div>
# 						</td>
# 						<td class='ddc-text-nowrap'><a href='/comments/codeine/for-pain.html' title='46 reviews for Pain'>46 reviews<span class='ddc-sr-only'> for Pain</span></a></td>
# 						<td class='ddc-text-nowrap'><a href='/condition/pain.html' title="Compare medications related to Pain">1155 medications</a></td>
# 					</tr>
# 																<tr>
# 						<th scope='row'>
# 							<span class='ddc-condition-label-wrap'>Diarrhea <span class='ddc-tag ddc-tag-info' title="This medication may not be approved by the FDA for the treatment of Diarrhea.">Off-label</span></span>
# 						</th>
# 						<td>
# 							<div class='ddc-rating-summary'>
# 								<div>9.3</div>
# 															</div>
# 						</td>
# 						<td class='ddc-text-nowrap'><a href='/comments/codeine/for-diarrhea.html' title='21 reviews for Diarrhea'>21 reviews<span class='ddc-sr-only'> for Diarrhea</span></a></td>
# 						<td class='ddc-text-nowrap'><a href='/condition/diarrhea.html' title="Compare medications related to Diarrhea">117 medications</a></td>
# 					</tr>
# 																<tr>
# 						<th scope='row'>
# 							<span class='ddc-condition-label-wrap'>Cough </span>
# 						</th>
# 						<td>
# 							<div class='ddc-rating-summary'>
# 								<div>9.5</div>
# 															</div>
# 						</td>
# 						<td class='ddc-text-nowrap'><a href='/comments/codeine/for-cough.html' title='4 reviews for Cough'>4 reviews<span class='ddc-sr-only'> for Cough</span></a></td>
# 						<td class='ddc-text-nowrap'><a href='/condition/cough.html' title="Compare medications related to Cough">829 medications</a></td>
# 					</tr>
# 																<tr>
# 						<th scope='row'>
# 							<span class='ddc-condition-label-wrap'>Chronic Pain </span>
# 						</th>
# 						<td>
# 							<div class='ddc-rating-summary'>
# 								<div>10.0</div>
# 															</div>
# 						</td>
# 						<td class='ddc-text-nowrap'><a href='/comments/codeine/for-chronic-pain.html' title='1 reviews for Chronic Pain'>1 reviews<span class='ddc-sr-only'> for Chronic Pain</span></a></td>
# 						<td class='ddc-text-nowrap'><a href='/condition/chronic-pain.html' title="Compare medications related to Chronic Pain">92 medications</a></td>
# 					</tr>
# 									</table>
# 	</div>
# 	<p class='ddc-mgb-4 noprint'><a class='ddc-btn ddc-btn-secondary' href='/members_comments_add/?ddc_id=718&amp;brand_name_id=0&amp;condition_id=0'>Write a review</a></p>
#
#
# 	<h2 id='reviews' class='ddc-anchor-offset'>Reviews for Codeine</h2>
#
#
# 	<form action='/comments/codeine/#reviews' method='get' class='ddc-mgb-2 noprint'>
# 		<div class='ddc-form-group-combo'>
# 			<div class='ddc-input-group-action'>
# 				<label>
# 					<span class='ddc-form-label-placeholder'>Search</span>
# 					<input type='text' name='search' value="" placeholder="Search" minlength='3' maxlength='30' autocapitalize='off' autocomplete='off' autocorrect='off'>
# 				</label>
# 				<button type='submit' class='ddc-btn' data-submit-loading>
# 					<span class='ddc-sr-only'>Search</span>
# 					<svg class='ddc-icon ddc-icon-search' width='20' height='20' viewBox='0 0 24 24' aria-hidden='true' focusable='false' xmlns='http://www.w3.org/2000/svg'><path d='M17 15.4c2.4-3.1 2.4-7.4 0-10.5C14.1 1.1 8.7.4 4.9 3.3 1.1 6.2.4 11.6 3.3 15.4c2.9 3.8 8.3 4.5 12.1 1.6l4.8 4.8 1.6-1.6-4.8-4.8Zm-6.9 1.1c-3.5 0-6.4-2.9-6.4-6.4 0-3.5 2.9-6.4 6.4-6.4 3.5 0 6.4 2.9 6.4 6.4 0 3.5-2.9 6.4-6.4 6.4Z' /></svg>
# 				</button>
# 			</div>
# 							<label for='sort_reviews'>
# 					<span class='ddc-form-label-placeholder'>Sort</span>
# 					<select class='ddc-form-select' style='width: 100%;' id='sort_reviews' name='sort_reviews' data-auto-submit>
# 													<option value='top' selected>Top reviews</option>
# 													<option value='most_recent'>Most recent</option>
# 													<option value='most_helpful'>Most helpful</option>
# 													<option value='highest_rating'>High rating</option>
# 													<option value='lowest_rating'>Low rating</option>
# 													<option value='time_on_medication'>Time on medication</option>
# 											</select>
# 				</label>
#
# 																		<input type='hidden' id='current-sfx' name='sfx' value=''>
# 										<b class='ddc-tag-group-title ddc-text-size-small'>Commonly mentioned side effects</b>
# 					<ul class='ddc-flex ddc-flex-wrap ddc-flex-gap-2 ddc-mg-0 ddc-list-unstyled'>
# 													<li class='ddc-mg-0 '>
# 																	<a href='/comments/codeine/sfx-constipation.html' class='ddc-btn ddc-btn-secondary ddc-btn-small'>constipation</a>
# 															</li>
# 													<li class='ddc-mg-0 '>
# 																	<a href='/comments/codeine/sfx-dizziness.html' class='ddc-btn ddc-btn-secondary ddc-btn-small'>dizziness</a>
# 															</li>
# 													<li class='ddc-mg-0 '>
# 																	<a href='/comments/codeine/sfx-drowsiness.html' class='ddc-btn ddc-btn-secondary ddc-btn-small'>drowsiness</a>
# 															</li>
# 													<li class='ddc-mg-0 '>
# 																	<a href='/comments/codeine/sfx-nausea.html' class='ddc-btn ddc-btn-secondary ddc-btn-small'>nausea</a>
# 															</li>
# 													<li class='ddc-mg-0 '>
# 																	<a href='/comments/codeine/sfx-addiction.html' class='ddc-btn ddc-btn-secondary ddc-btn-small'>addiction</a>
# 															</li>
# 													<li class='ddc-mg-0 is-hidden'>
# 																	<a href='/comments/codeine/sfx-diarrhea.html' class='ddc-btn ddc-btn-secondary ddc-btn-small'>diarrhea</a>
# 															</li>
# 													<li class='ddc-mg-0 is-hidden'>
# 																	<a href='/comments/codeine/sfx-lightheadedness.html' class='ddc-btn ddc-btn-secondary ddc-btn-small'>lightheadedness</a>
# 															</li>
# 																			<li class='ddc-mg-0'>
# 								<button value='expand' class='ddc-btn ddc-btn-secondary ddc-btn-small' onclick="this.parentElement.parentElement.querySelectorAll('.is-hidden').forEach(el => el.classList.remove('is-hidden')); this.parentElement.remove(); return false;">+ 2 more</button>
# 							</li>
# 											</ul>
# 									</div>
# 	</form>
#
# 	<div class='ddc-comment ddc-box ddc-mgb-2'>
# 		<ul class='ddc-mgb-1 ddc-list-inline ddc-text-color-secondary ddc-text-size-small ddc-comment-header'>
# 			<li><abbr class='no-border' title='For privacy reasons, full names are not displayed.'>dal...</abbr></li>
# 							<li>Taken for less than 1 month</li>
# 						<li>January 12, 2021</li>
# 		</ul>
#
# 		<p><b>For Diarrhea</b> 							&quot;I suffer from IBS and Diverticulitis and, although I have a repeat prescription for mebeverine (which sometimes works and sometimes doesn&#039;t), I haven&#039;t had a solid bowel movement for ages. As any sufferers know, the urgent need for the toilet only minutes after eating anything really does get you down after long periods, and it&#039;s sometimes easier to just not eat at all if I&#039;m out somewhere. EXCEPT when I have been prescribed codeine for unrelated symptoms (back pain, whiplash, etc), at which point, by some magic, my IBS vanishes overnight and my digestive system genuinely returns to &#039;normal&#039;. I&#039;ve only ever taken low doses of codeine (2 or 3 30mg tablets in 24 hours) and never felt any other side effects, including drowsiness. Is it out of the question for it to be prescribed as a treatment, given its apparently addictive nature?&quot;
# 					</p>
#
# 					<div class='ddc-rating-summary ddc-mgb-1'>
# 				<div>10 / 10</div>
# 				<div class='ddc-rating-bar' role='img'>
# <div style='width: 100.0%;' aria-hidden='true'></div>
# </div>
# 			</div>
#
# 		<div class='ddc-comment-actions noprint'>
# 			<div data-load-html-target>
# 				<span>Was this helpful?</span><a href='#' data-load-html='/api/reviews/feedback/' data-vote='1' data-id='327100' rel='nofollow'>Yes</a><a href='#' data-load-html='/api/reviews/feedback/' data-vote='-1' data-id='327100' rel='nofollow'>No</a>
# 			</div>
#
# 			<div data-load-html-target>
# 				<span data-load-html-target>
# 					<a href='#' data-load-html='/api/reviews/feedback/' data-like='1' data-id='327100' rel='nofollow'><svg class='ddc-icon ddc-icon-voteup' width='20' height='20' viewBox='0 0 24 24' aria-hidden='true' focusable='false' xmlns='http://www.w3.org/2000/svg'><path d='M19.5 9H15V4.5a2.253 2.253 0 0 0-2.25-2.25h-1.6a1.507 1.507 0 0 0-1.485 1.288l-.634 4.437L6.35 12H1.5v10.5h15.75a5.256 5.256 0 0 0 5.25-5.25V12a3.003 3.003 0 0 0-3-3ZM6 21H3v-7.5h3V21Zm15-3.75A3.754 3.754 0 0 1 17.25 21H7.5v-8.023l2.968-4.452.682-4.775h1.6a.75.75 0 0 1 .75.75v6h6A1.502 1.502 0 0 1 21 12v5.25Z' /></svg>99</a>
# 				</span>
# 				<a href='#' data-load-html='/api/reviews/feedback/' data-report='1' data-id='327100' rel='nofollow'>Report</a>
# 			</div>
# 		</div>
# 	</div>
# 				<div class='ddc-comment ddc-box ddc-mgb-2'>
# 		<ul class='ddc-mgb-1 ddc-list-inline ddc-text-color-secondary ddc-text-size-small ddc-comment-header'>
# 			<li><abbr class='no-border' title='For privacy reasons, full names are not displayed.'>Sla...</abbr></li>
# 							<li>Taken for 5 to 10 years</li>
# 						<li>October 10, 2020</li>
# 		</ul>
#
# 		<p><b>For Diarrhea</b> 							&quot;Had my gallbladder out over 10 years ago and started getting bad, frequent diarrhea and gastric reflux. After many tests, I was diagnosed with post-cholecystectomy syndrome. Chronic diarrhea left me terrified to leave the house. After years of trial and error, my doctor prescribed codeine. I accept I am addicted, but it is so much better than the alternative.&quot;
# 					</p>
#
# 					<div class='ddc-rating-summary ddc-mgb-1'>
# 				<div>9 / 10</div>
# 				<div class='ddc-rating-bar' role='img'>
# <div style='width: 90.0%;' aria-hidden='true'></div>
# </div>
# 			</div>
#
# 		<div class='ddc-comment-actions noprint'>
# 			<div data-load-html-target>
# 				<span>Was this helpful?</span><a href='#' data-load-html='/api/reviews/feedback/' data-vote='1' data-id='317602' rel='nofollow'>Yes</a><a href='#' data-load-html='/api/reviews/feedback/' data-vote='-1' data-id='317602' rel='nofollow'>No</a>
# 			</div>
#
# 			<div data-load-html-target>
# 				<span data-load-html-target>
# 					<a href='#' data-load-html='/api/reviews/feedback/' data-like='1' data-id='317602' rel='nofollow'><svg class='ddc-icon ddc-icon-voteup' width='20' height='20' viewBox='0 0 24 24' aria-hidden='true' focusable='false' xmlns='http://www.w3.org/2000/svg'><path d='M19.5 9H15V4.5a2.253 2.253 0 0 0-2.25-2.25h-1.6a1.507 1.507 0 0 0-1.485 1.288l-.634 4.437L6.35 12H1.5v10.5h15.75a5.256 5.256 0 0 0 5.25-5.25V12a3.003 3.003 0 0 0-3-3ZM6 21H3v-7.5h3V21Zm15-3.75A3.754 3.754 0 0 1 17.25 21H7.5v-8.023l2.968-4.452.682-4.775h1.6a.75.75 0 0 1 .75.75v6h6A1.502 1.502 0 0 1 21 12v5.25Z' /></svg>59</a>
# 				</span>
# 				<a href='#' data-load-html='/api/reviews/feedback/' data-report='1' data-id='317602' rel='nofollow'>Report</a>
# 			</div>
# 		</div>
# 	</div>
# 				<div class='ddc-comment ddc-box ddc-mgb-2'>
# 		<ul class='ddc-mgb-1 ddc-list-inline ddc-text-color-secondary ddc-text-size-small ddc-comment-header'>
# 			<li><abbr class='no-border' title='For privacy reasons, full names are not displayed.'>Pai...</abbr></li>
# 							<li>Taken for 1 to 2 years</li>
# 						<li>October 29, 2018</li>
# 		</ul>
#
# 		<p><b>For Pain</b> 							&quot;I am 20 years old. I have been suffering from generalized anxiety disorder for 4 years. For me, the biggest problem of the wide range related to chronic anxiety is chronic pain: huge muscle cramps in my shoulders and neck, as well as back pain, bruxism during the day and night, and frequent headaches. Codeine 30 mg every 6 hours helps me level all of these issues so that I am able to study my university subjects. It has been the only painkiller that has helped me so far... I am lucky to have an understanding doctor, given how much they are demonizing this helpful medication due to some irresponsible people.&quot;
# 					</p>
#
# 					<div class='ddc-rating-summary ddc-mgb-1'>
# 				<div>9 / 10</div>
# 				<div class='ddc-rating-bar' role='img'>
# <div style='width: 90.0%;' aria-hidden='true'></div>
# </div>
# 			</div>
#
# 		<div class='ddc-comment-actions noprint'>
# 			<div data-load-html-target>
# 				<span>Was this helpful?</span><a href='#' data-load-html='/api/reviews/feedback/' data-vote='1' data-id='240874' rel='nofollow'>Yes</a><a href='#' data-load-html='/api/reviews/feedback/' data-vote='-1' data-id='240874' rel='nofollow'>No</a>
# 			</div>
#
# 			<div data-load-html-target>
# 				<span data-load-html-target>
# 					<a href='#' data-load-html='/api/reviews/feedback/' data-like='1' data-id='240874' rel='nofollow'><svg class='ddc-icon ddc-icon-voteup' width='20' height='20' viewBox='0 0 24 24' aria-hidden='true' focusable='false' xmlns='http://www.w3.org/2000/svg'><path d='M19.5 9H15V4.5a2.253 2.253 0 0 0-2.25-2.25h-1.6a1.507 1.507 0 0 0-1.485 1.288l-.634 4.437L6.35 12H1.5v10.5h15.75a5.256 5.256 0 0 0 5.25-5.25V12a3.003 3.003 0 0 0-3-3ZM6 21H3v-7.5h3V21Zm15-3.75A3.754 3.754 0 0 1 17.25 21H7.5v-8.023l2.968-4.452.682-4.775h1.6a.75.75 0 0 1 .75.75v6h6A1.502 1.502 0 0 1 21 12v5.25Z' /></svg>68</a>
# 				</span>
# 				<a href='#' data-load-html='/api/reviews/feedback/' data-report='1' data-id='240874' rel='nofollow'>Report</a>
# 			</div>
# 		</div>
# 	</div>
#
# <h3>Frequently asked questions</h3>
# <ul class='ddc-mgb-4'>
# 			<li><a href='/medical-answers/tramadol-stronger-codeine-3562487/'>Is tramadol stronger than codeine?</a></li>
# 			<li><a href='/medical-answers/what-drugs-cause-pinpoint-pupils-3580157/'>What drugs cause pinpoint pupils​?</a></li>
# 			<li><a href='/medical-answers/drugs-opioid-induced-constipation-3573711/'>Which drugs cause opioid-induced constipation?</a></li>
# 			<li><a href='/medical-answers/which-painkiller-should-you-use-3561205/'>Which painkiller should you use?</a></li>
# 	</ul>
# 				<div class='ddc-comment ddc-box ddc-mgb-2'>
# 		<ul class='ddc-mgb-1 ddc-list-inline ddc-text-color-secondary ddc-text-size-small ddc-comment-header'>
# 			<li><abbr class='no-border' title='For privacy reasons, full names are not displayed.'>Ins...</abbr></li>
# 							<li>Taken for 10 years or more</li>
# 						<li>January 16, 2020</li>
# 		</ul>
#
# 		<p><b>For Diarrhea</b> 							&quot;I had my gallbladder removed in 2000. Not long after, I started having other problems and was eventually diagnosed with IBS. I have taken a number of different drugs, but codeine was the only one that calmed my stomach down and helped me get through the day. I take 30 mg of codeine every night. Occasionally, if I&#039;m stressed, I take another 30 mg, but that&#039;s it. I don&#039;t think I could continue without it.&quot;
# 					</p>
#
# 					<div class='ddc-rating-summary ddc-mgb-1'>
# 				<div>10 / 10</div>
# 				<div class='ddc-rating-bar' role='img'>
# <div style='width: 100.0%;' aria-hidden='true'></div>
# </div>
# 			</div>
#
# 		<div class='ddc-comment-actions noprint'>
# 			<div data-load-html-target>
# 				<span>Was this helpful?</span><a href='#' data-load-html='/api/reviews/feedback/' data-vote='1' data-id='288260' rel='nofollow'>Yes</a><a href='#' data-load-html='/api/reviews/feedback/' data-vote='-1' data-id='288260' rel='nofollow'>No</a>
# 			</div>
#
# 			<div data-load-html-target>
# 				<span data-load-html-target>
# 					<a href='#' data-load-html='/api/reviews/feedback/' data-like='1' data-id='288260' rel='nofollow'><svg class='ddc-icon ddc-icon-voteup' width='20' height='20' viewBox='0 0 24 24' aria-hidden='true' focusable='false' xmlns='http://www.w3.org/2000/svg'><path d='M19.5 9H15V4.5a2.253 2.253 0 0 0-2.25-2.25h-1.6a1.507 1.507 0 0 0-1.485 1.288l-.634 4.437L6.35 12H1.5v10.5h15.75a5.256 5.256 0 0 0 5.25-5.25V12a3.003 3.003 0 0 0-3-3ZM6 21H3v-7.5h3V21Zm15-3.75A3.754 3.754 0 0 1 17.25 21H7.5v-8.023l2.968-4.452.682-4.775h1.6a.75.75 0 0 1 .75.75v6h6A1.502 1.502 0 0 1 21 12v5.25Z' /></svg>47</a>
# 				</span>
# 				<a href='#' data-load-html='/api/reviews/feedback/' data-report='1' data-id='288260' rel='nofollow'>Report</a>
# 			</div>
# 		</div>
# 	</div>
# 				<div class='ddc-comment ddc-box ddc-mgb-2'>
# 		<ul class='ddc-mgb-1 ddc-list-inline ddc-text-color-secondary ddc-text-size-small ddc-comment-header'>
# 			<li><abbr class='no-border' title='For privacy reasons, full names are not displayed.'>pxb...</abbr></li>
# 						<li>January 28, 2009</li>
# 		</ul>
#
# 		<p><b>For Pain</b> 							&quot;Very effective. I have osteoarthritis and can be pain-free with codeine. It is more effective with ibuprofen. Also, profoundly lifts depression due to chronic pain and makes life better day-to-day. Space doses well apart to avoid tolerance. I use only in the morning with very good effect. Using the whole daily dose in the morning may get you through the day without a need for a second dose. I would leave at least 6 hours between doses to ensure full effect. Don&#039;t suffer needlessly. Good luck and hope this helps.&quot;
# 					</p>
#
# 					<div class='ddc-rating-summary ddc-mgb-1'>
# 				<div>10 / 10</div>
# 				<div class='ddc-rating-bar' role='img'>
# <div style='width: 100.0%;' aria-hidden='true'></div>
# </div>
# 			</div>
#
# 		<div class='ddc-comment-actions noprint'>
# 			<div data-load-html-target>
# 				<span>Was this helpful?</span><a href='#' data-load-html='/api/reviews/feedback/' data-vote='1' data-id='15827' rel='nofollow'>Yes</a><a href='#' data-load-html='/api/reviews/feedback/' data-vote='-1' data-id='15827' rel='nofollow'>No</a>
# 			</div>
#
# 			<div data-load-html-target>
# 				<span data-load-html-target>
# 					<a href='#' data-load-html='/api/reviews/feedback/' data-like='1' data-id='15827' rel='nofollow'><svg class='ddc-icon ddc-icon-voteup' width='20' height='20' viewBox='0 0 24 24' aria-hidden='true' focusable='false' xmlns='http://www.w3.org/2000/svg'><path d='M19.5 9H15V4.5a2.253 2.253 0 0 0-2.25-2.25h-1.6a1.507 1.507 0 0 0-1.485 1.288l-.634 4.437L6.35 12H1.5v10.5h15.75a5.256 5.256 0 0 0 5.25-5.25V12a3.003 3.003 0 0 0-3-3ZM6 21H3v-7.5h3V21Zm15-3.75A3.754 3.754 0 0 1 17.25 21H7.5v-8.023l2.968-4.452.682-4.775h1.6a.75.75 0 0 1 .75.75v6h6A1.502 1.502 0 0 1 21 12v5.25Z' /></svg>94</a>
# 				</span>
# 				<a href='#' data-load-html='/api/reviews/feedback/' data-report='1' data-id='15827' rel='nofollow'>Report</a>
# 			</div>
# 		</div>
# 	</div>
#
# <div class='ddc-box ddc-box-info ddc-box-review-summary ddc-flex ddc-flex-items-center ddc-mgt-4 noprint'>
# 	<div class='ddc-flex ddc-flex-column'>
# 		<h3 class='ddc-mg-0'>Are you taking this medicine?</h3>
# 		<span>Your review helps others make informed decisions.</span>
# 	</div>
# 	<a class='ddc-btn' href='/members_comments_add/?ddc_id=718&amp;brand_name_id=0&amp;condition_id=0'>Write a review</a>
# </div>
# 			<div class='ddc-comment ddc-box ddc-mgb-2'>
# 		<ul class='ddc-mgb-1 ddc-list-inline ddc-text-color-secondary ddc-text-size-small ddc-comment-header'>
# 			<li><abbr class='no-border' title='For privacy reasons, full names are not displayed.'>Dex...</abbr></li>
# 						<li>November 30, 2019</li>
# 		</ul>
#
# 		<p><b>For Pain</b> 							&quot;I need Codeine for the pain of fibromyalgia and take 8 codeine phosphate daily. But I&#039;m going to be tapered off due to the addiction epidemic. It&#039;s unfair on genuine patients that some abuse it, which puts changes to guidelines on prescriptions. Just because some go on their crusades to change laws puts pressure on others.&quot;
# 					</p>
#
# 					<div class='ddc-rating-summary ddc-mgb-1'>
# 				<div>9 / 10</div>
# 				<div class='ddc-rating-bar' role='img'>
# <div style='width: 90.0%;' aria-hidden='true'></div>
# </div>
# 			</div>
#
# 		<div class='ddc-comment-actions noprint'>
# 			<div data-load-html-target>
# 				<span>Was this helpful?</span><a href='#' data-load-html='/api/reviews/feedback/' data-vote='1' data-id='282134' rel='nofollow'>Yes</a><a href='#' data-load-html='/api/reviews/feedback/' data-vote='-1' data-id='282134' rel='nofollow'>No</a>
# 			</div>
#
# 			<div data-load-html-target>
# 				<span data-load-html-target>
# 					<a href='#' data-load-html='/api/reviews/feedback/' data-like='1' data-id='282134' rel='nofollow'><svg class='ddc-icon ddc-icon-voteup' width='20' height='20' viewBox='0 0 24 24' aria-hidden='true' focusable='false' xmlns='http://www.w3.org/2000/svg'><path d='M19.5 9H15V4.5a2.253 2.253 0 0 0-2.25-2.25h-1.6a1.507 1.507 0 0 0-1.485 1.288l-.634 4.437L6.35 12H1.5v10.5h15.75a5.256 5.256 0 0 0 5.25-5.25V12a3.003 3.003 0 0 0-3-3ZM6 21H3v-7.5h3V21Zm15-3.75A3.754 3.754 0 0 1 17.25 21H7.5v-8.023l2.968-4.452.682-4.775h1.6a.75.75 0 0 1 .75.75v6h6A1.502 1.502 0 0 1 21 12v5.25Z' /></svg>46</a>
# 				</span>
# 				<a href='#' data-load-html='/api/reviews/feedback/' data-report='1' data-id='282134' rel='nofollow'>Report</a>
# 			</div>
# 		</div>
# 	</div>
# 				<div class='ddc-comment ddc-box ddc-mgb-2'>
# 		<ul class='ddc-mgb-1 ddc-list-inline ddc-text-color-secondary ddc-text-size-small ddc-comment-header'>
# 			<li><abbr class='no-border' title='For privacy reasons, full names are not displayed.'>DBI...</abbr></li>
# 						<li>December 2, 2008</li>
# 		</ul>
#
# 		<p><b>For Diarrhea</b> 							&quot;I have severe IBS (Irritable Bowel Syndrome) and could not find relief until I was prescribed codeine for it. At this point, most of my symptoms are either completely gone or nearly gone. I can say that codeine is a wonder drug when it comes to resolving the symptoms.&quot;
# 					</p>
#
# 					<div class='ddc-rating-summary ddc-mgb-1'>
# 				<div>10 / 10</div>
# 				<div class='ddc-rating-bar' role='img'>
# <div style='width: 100.0%;' aria-hidden='true'></div>
# </div>
# 			</div>
#
# 		<div class='ddc-comment-actions noprint'>
# 			<div data-load-html-target>
# 				<span>Was this helpful?</span><a href='#' data-load-html='/api/reviews/feedback/' data-vote='1' data-id='13306' rel='nofollow'>Yes</a><a href='#' data-load-html='/api/reviews/feedback/' data-vote='-1' data-id='13306' rel='nofollow'>No</a>
# 			</div>
#
# 			<div data-load-html-target>
# 				<span data-load-html-target>
# 					<a href='#' data-load-html='/api/reviews/feedback/' data-like='1' data-id='13306' rel='nofollow'><svg class='ddc-icon ddc-icon-voteup' width='20' height='20' viewBox='0 0 24 24' aria-hidden='true' focusable='false' xmlns='http://www.w3.org/2000/svg'><path d='M19.5 9H15V4.5a2.253 2.253 0 0 0-2.25-2.25h-1.6a1.507 1.507 0 0 0-1.485 1.288l-.634 4.437L6.35 12H1.5v10.5h15.75a5.256 5.256 0 0 0 5.25-5.25V12a3.003 3.003 0 0 0-3-3ZM6 21H3v-7.5h3V21Zm15-3.75A3.754 3.754 0 0 1 17.25 21H7.5v-8.023l2.968-4.452.682-4.775h1.6a.75.75 0 0 1 .75.75v6h6A1.502 1.502 0 0 1 21 12v5.25Z' /></svg>83</a>
# 				</span>
# 				<a href='#' data-load-html='/api/reviews/feedback/' data-report='1' data-id='13306' rel='nofollow'>Report</a>
# 			</div>
# 		</div>
# 	</div>
#
# <h3>More FAQ</h3>
# <ul class='ddc-mgb-4'>
# 			<li><a href='/medical-answers/difference-between-par-promethazine-codeine-tech-3173235/'>Par promethazine with codeine vs Hi-Tech promethazine with codeine?</a></li>
# 			<li><a href='/medical-answers/adco-napacod-3567003/'>What is Adco-Napacod used for?</a></li>
# 	</ul>
# 		<div class='ddc-comment ddc-box ddc-mgb-2'>
# 		<ul class='ddc-mgb-1 ddc-list-inline ddc-text-color-secondary ddc-text-size-small ddc-comment-header'>
# 			<li><abbr class='no-border' title='For privacy reasons, full names are not displayed.'>Dea...</abbr></li>
# 							<li>Taken for 10 years or more</li>
# 						<li>November 21, 2019</li>
# 		</ul>
#
# 		<p><b>For Diarrhea</b> 							&quot;I have been taking Tylenol 3 for 15 years for my IBS. I was able to live a good life and work, but now at 65, the night is full of trips to the bathroom, and the doctors have told me I must get off the codeine as it is ruining my colon. I was on 3-4 daily and 4-6 Lomotil daily. I am now one month in withdrawal. I go to the bathroom 15-30 times a day. Nothing can be done for me for 6 months, so they say. This is a real drag. I am totally homebound at this point. Withdrawal is really tough, but I have no desire for the drug emotionally, just for the constipation effects. Trying the FODMAP diet, but it has made no difference yet.&quot;
# 					</p>
#
# 					<div class='ddc-rating-summary ddc-mgb-1'>
# 				<div>3 / 10</div>
# 				<div class='ddc-rating-bar' role='img'>
# <div style='width: 30.0%;' aria-hidden='true'></div>
# </div>
# 			</div>
#
# 		<div class='ddc-comment-actions noprint'>
# 			<div data-load-html-target>
# 				<span>Was this helpful?</span><a href='#' data-load-html='/api/reviews/feedback/' data-vote='1' data-id='280898' rel='nofollow'>Yes</a><a href='#' data-load-html='/api/reviews/feedback/' data-vote='-1' data-id='280898' rel='nofollow'>No</a>
# 			</div>
#
# 			<div data-load-html-target>
# 				<span data-load-html-target>
# 					<a href='#' data-load-html='/api/reviews/feedback/' data-like='1' data-id='280898' rel='nofollow'><svg class='ddc-icon ddc-icon-voteup' width='20' height='20' viewBox='0 0 24 24' aria-hidden='true' focusable='false' xmlns='http://www.w3.org/2000/svg'><path d='M19.5 9H15V4.5a2.253 2.253 0 0 0-2.25-2.25h-1.6a1.507 1.507 0 0 0-1.485 1.288l-.634 4.437L6.35 12H1.5v10.5h15.75a5.256 5.256 0 0 0 5.25-5.25V12a3.003 3.003 0 0 0-3-3ZM6 21H3v-7.5h3V21Zm15-3.75A3.754 3.754 0 0 1 17.25 21H7.5v-8.023l2.968-4.452.682-4.775h1.6a.75.75 0 0 1 .75.75v6h6A1.502 1.502 0 0 1 21 12v5.25Z' /></svg>35</a>
# 				</span>
# 				<a href='#' data-load-html='/api/reviews/feedback/' data-report='1' data-id='280898' rel='nofollow'>Report</a>
# 			</div>
# 		</div>
# 	</div>
# 				<div class='ddc-comment ddc-box ddc-mgb-2'>
# 		<ul class='ddc-mgb-1 ddc-list-inline ddc-text-color-secondary ddc-text-size-small ddc-comment-header'>
# 			<li><abbr class='no-border' title='For privacy reasons, full names are not displayed.'>CW5...</abbr></li>
# 						<li>March 6, 2016</li>
# 		</ul>
#
# 		<p><b>For Diarrhea</b> 							&quot;3 bowel resections due to Crohn&#039;s disease. I now have short bowel syndrome with chronic diarrhea. I have tried every anti-diarrheal drug there is, and the only one that has helped is codeine. I consider it a wonder drug for my condition, enabling me to lead a mostly normal life. I have taken the same amount every day for 6 years. I don&#039;t feel &#039;high&#039;, but do feel slightly drowsy occasionally. I did have a period of 8 months where I stopped taking it, and while I did have some physical symptoms (not mental) in stopping, they were not too bad. The symptom relief I had on the drug far outweighed the negatives. I continue to take it, and it makes my life easier.&quot;
# 					</p>
#
# 					<div class='ddc-rating-summary ddc-mgb-1'>
# 				<div>9 / 10</div>
# 				<div class='ddc-rating-bar' role='img'>
# <div style='width: 90.0%;' aria-hidden='true'></div>
# </div>
# 			</div>
#
# 		<div class='ddc-comment-actions noprint'>
# 			<div data-load-html-target>
# 				<span>Was this helpful?</span><a href='#' data-load-html='/api/reviews/feedback/' data-vote='1' data-id='153286' rel='nofollow'>Yes</a><a href='#' data-load-html='/api/reviews/feedback/' data-vote='-1' data-id='153286' rel='nofollow'>No</a>
# 			</div>
#
# 			<div data-load-html-target>
# 				<span data-load-html-target>
# 					<a href='#' data-load-html='/api/reviews/feedback/' data-like='1' data-id='153286' rel='nofollow'><svg class='ddc-icon ddc-icon-voteup' width='20' height='20' viewBox='0 0 24 24' aria-hidden='true' focusable='false' xmlns='http://www.w3.org/2000/svg'><path d='M19.5 9H15V4.5a2.253 2.253 0 0 0-2.25-2.25h-1.6a1.507 1.507 0 0 0-1.485 1.288l-.634 4.437L6.35 12H1.5v10.5h15.75a5.256 5.256 0 0 0 5.25-5.25V12a3.003 3.003 0 0 0-3-3ZM6 21H3v-7.5h3V21Zm15-3.75A3.754 3.754 0 0 1 17.25 21H7.5v-8.023l2.968-4.452.682-4.775h1.6a.75.75 0 0 1 .75.75v6h6A1.502 1.502 0 0 1 21 12v5.25Z' /></svg>42</a>
# 				</span>
# 				<a href='#' data-load-html='/api/reviews/feedback/' data-report='1' data-id='153286' rel='nofollow'>Report</a>
# 			</div>
# 		</div>
# 	</div>
# 				<div class='ddc-comment ddc-box ddc-mgb-2'>
# 		<ul class='ddc-mgb-1 ddc-list-inline ddc-text-color-secondary ddc-text-size-small ddc-comment-header'>
# 			<li><abbr class='no-border' title='For privacy reasons, full names are not displayed.'>Ouc...</abbr></li>
# 						<li>October 3, 2014</li>
# 		</ul>
#
# 		<p><b>For Pain</b> 							&quot;I have extreme toothache, where no amount of paracetamol or ibuprofen can take it off. I have been using codeine to take away the pain, and it works. The only downside is feeling very, very sick and cannot even face food, and feeling shaky/drunk.&quot;
# 					</p>
#
# 					<div class='ddc-rating-summary ddc-mgb-1'>
# 				<div>8 / 10</div>
# 				<div class='ddc-rating-bar' role='img'>
# <div style='width: 80.0%;' aria-hidden='true'></div>
# </div>
# 			</div>
#
# 		<div class='ddc-comment-actions noprint'>
# 			<div data-load-html-target>
# 				<span>Was this helpful?</span><a href='#' data-load-html='/api/reviews/feedback/' data-vote='1' data-id='107609' rel='nofollow'>Yes</a><a href='#' data-load-html='/api/reviews/feedback/' data-vote='-1' data-id='107609' rel='nofollow'>No</a>
# 			</div>
#
# 			<div data-load-html-target>
# 				<span data-load-html-target>
# 					<a href='#' data-load-html='/api/reviews/feedback/' data-like='1' data-id='107609' rel='nofollow'><svg class='ddc-icon ddc-icon-voteup' width='20' height='20' viewBox='0 0 24 24' aria-hidden='true' focusable='false' xmlns='http://www.w3.org/2000/svg'><path d='M19.5 9H15V4.5a2.253 2.253 0 0 0-2.25-2.25h-1.6a1.507 1.507 0 0 0-1.485 1.288l-.634 4.437L6.35 12H1.5v10.5h15.75a5.256 5.256 0 0 0 5.25-5.25V12a3.003 3.003 0 0 0-3-3ZM6 21H3v-7.5h3V21Zm15-3.75A3.754 3.754 0 0 1 17.25 21H7.5v-8.023l2.968-4.452.682-4.775h1.6a.75.75 0 0 1 .75.75v6h6A1.502 1.502 0 0 1 21 12v5.25Z' /></svg>45</a>
# 				</span>
# 				<a href='#' data-load-html='/api/reviews/feedback/' data-report='1' data-id='107609' rel='nofollow'>Report</a>
# 			</div>
# 		</div>
# 	</div>
# 				<div class='ddc-comment ddc-box ddc-mgb-2'>
# 		<ul class='ddc-mgb-1 ddc-list-inline ddc-text-color-secondary ddc-text-size-small ddc-comment-header'>
# 			<li><abbr class='no-border' title='For privacy reasons, full names are not displayed.'>Hom...</abbr></li>
# 							<li>Taken for 1 to 6 months</li>
# 						<li>June 22, 2016</li>
# 		</ul>
#
# 		<p><b>For Pain</b> 							&quot;I am an early 60&#039;s male with chronic neck pain as a result of too many skiing accidents over many years. Normal painkillers like Aspirin or Naprosan wouldn&#039;t even touch the pain, however, I found Paracetamol/Codeine 500mg/30mg worked wonders. I take 1 tablet at first, and if the pain is too intense, I increase to 2 tablets. Because of stomach upsets and slight dizziness, I limit myself to 4 tablets daily. Talking to my GP about the situation and the fact that I did not want to stay long-term on the Paracetamol/Codeine, he suggested acupuncture, which I started to have 2 times a week (10 very sharp but small needles) over a period of 6 weeks, and as a result, I have only had 1 of my tablets for the last fortnight, which is a wonderful turnaround for me.&quot;
# 					</p>
#
# 					<div class='ddc-rating-summary ddc-mgb-1'>
# 				<div>10 / 10</div>
# 				<div class='ddc-rating-bar' role='img'>
# <div style='width: 100.0%;' aria-hidden='true'></div>
# </div>
# 			</div>
#
# 		<div class='ddc-comment-actions noprint'>
# 			<div data-load-html-target>
# 				<span>Was this helpful?</span><a href='#' data-load-html='/api/reviews/feedback/' data-vote='1' data-id='164286' rel='nofollow'>Yes</a><a href='#' data-load-html='/api/reviews/feedback/' data-vote='-1' data-id='164286' rel='nofollow'>No</a>
# 			</div>
#
# 			<div data-load-html-target>
# 				<span data-load-html-target>
# ...
# 						<span class='ddc-sr-only'>Download the Medication Guide app on the Google Play store</span>
# 						<img src='/img/v-20250930/apps/google-play.png' loading='lazy' width='149' height='44' alt='' aria-hidden='true'>
# 					</a>
# 				</div>
# 			</div>
#
# 			<div class='ddc-footer-promo-image'>
# 				<picture>
# 					<source srcset='/img/v-20250709/apps/promo-uberapp-large.png' media='(min-width: 768px)'>
# 					<img src='/img/v-20250709/apps/promo-uberapp.png' width='334' height='252' loading='lazy' alt='Drugs.com mobile app'>
# 				</picture>
# 			</div>
# 		</div>
#
# 		<nav class='ddc-footer-navigation' aria-label='Informational and social site links'>
# 			<div class='ddc-footer-column-logo'>
# 				<a href='/'>
# 					<span class='ddc-sr-only'>Drugs.com</span>
# 					<img src='/img/logo/drugscom-logo-mark.svg' loading='lazy' alt='' aria-hidden='true'>
# 				</a>
# 			</div>
#
# 			<div class='ddc-footer-column ddc-flex ddc-flex-column ddc-flex-gap-4'>
# 				<b class='ddc-footer-column-title'>About</b>
# 				<ul class='ddc-flex ddc-flex-column ddc-flex-gap-2 ddc-list-unstyled ddc-mg-0 ddc-text-size-small'>
# 					<li><a href='/support/about.html'>About Drugs.com</a></li>
# 					<li><a href='/support/advertising.html'>Advertising policy</a></li>
# 					<li><a href='/support/citations.html'>Attribution &amp; citations</a></li>
# 					<li><a href='//podcasts.drugs.com/' target='_blank' rel='noopener noreferrer'>Drugs.com Podcast</a></li>
# 				</ul>
# 			</div>
#
# 			<div class='ddc-footer-column ddc-flex ddc-flex-column ddc-flex-gap-4'>
# 				<b class='ddc-footer-column-title'>Terms &amp; privacy</b>
# 				<ul class='ddc-flex ddc-flex-column ddc-flex-gap-2 ddc-list-unstyled ddc-mg-0 ddc-text-size-small'>
# 					<li><a href='/support/terms.html'>Terms of use</a></li>
# 					<li><a href='/support/editorial-policy.html'>Editorial policy</a></li>
# 					<li><a href='/support/privacy.html'>Privacy policy</a>
# 											</li>
# 									</ul>
# 			</div>
#
# 			<div class='ddc-footer-column ddc-flex ddc-flex-column ddc-flex-gap-4'>
# 				<b class='ddc-footer-column-title'>Support</b>
# 				<ul class='ddc-flex ddc-flex-column ddc-flex-gap-2 ddc-list-unstyled ddc-mg-0 ddc-text-size-small'>
# 					<li><a href='/support/'>Help center</a></li>
# 					<li><a href='/sitemap.html'>Sitemap</a></li>
# 					<li><a href='/support/contact.html'>Contact us</a></li>
# 					<li><a href='/support/accessibility.html'>Accessibility</a></li>
# 				</ul>
# 			</div>
#
# 			<div class='ddc-footer-column-social ddc-flex ddc-flex-column ddc-flex-gap-4'>
# 									<ul class='ddc-flex ddc-flex-wrap ddc-flex-gap-4 ddc-list-unstyled ddc-mg-0'>
# 						<li>
# 							<a href='/newsletters/'>
# 								<span class='ddc-sr-only'>Subscribe to Drugs.com newsletters</span>
# 								<svg class='ddc-icon ddc-icon-emailfilled' width='24' height='24' viewBox='0 0 24 24' aria-hidden='true' focusable='false' xmlns='http://www.w3.org/2000/svg'><path d='M20.5 4.5h-17a2 2 0 0 0-2 2v11a2 2 0 0 0 2 2h17a2 2 0 0 0 2-2v-11a2 2 0 0 0-2-2Zm-.57 2.864-7.5 5.25a.75.75 0 0 1-.86 0l-7.5-5.25a.75.75 0 1 1 .86-1.228v-.001l7.07 4.95 7.07-4.949a.75.75 0 0 1 .86 1.228Z' /></svg>							</a>
# 						</li>
# 						<li>
# 							<a href='//www.facebook.com/Drugscom' target='_blank' rel='noopener noreferrer'>
# 								<span class='ddc-sr-only'>Follow Drugs.com on Facebook</span>
# 								<svg class='ddc-icon ddc-icon-facebook' width='24' height='24' viewBox='0 0 24 24' aria-hidden='true' focusable='false' xmlns='http://www.w3.org/2000/svg'><path d='M14 6.54c-2.06 0-3.4 1.25-3.4 3.52v2H8.3v2.61h2.3V21A9.04 9.04 0 013 12.05C3 7.05 7.03 3 12 3s9 4.05 9 9.05c0 4.53-3.3 8.27-7.6 8.95v-6.33h2.1l.4-2.62h-2.5v-1.7c0-.7.35-1.4 1.47-1.4h1.14V6.7s-1.03-.17-2.02-.17z' /></svg>							</a>
# 						</li>
# 						<li>
# 							<a href='//x.com/drugscom' target='_blank' rel='noopener noreferrer'>
# 								<span class='ddc-sr-only'>Follow Drugs.com on X (Twitter)</span>
# 								<svg class='ddc-icon ddc-icon-twitter' width='24' height='24' viewBox='0 0 24 24' aria-hidden='true' focusable='false' xmlns='http://www.w3.org/2000/svg'><path d='M13.6935 10.614L20.382 3H18.7972L12.987 9.60975L8.34975 3H3L10.014 12.996L3 20.9797H4.58475L10.7167 13.998L15.615 20.9797H20.9647L13.6935 10.614ZM11.5222 13.0837L10.8105 12.0877L5.15625 4.17H7.59075L12.1552 10.5623L12.864 11.5583L18.7965 19.8668H16.362L11.5222 13.0837Z' /></svg>							</a>
# 						</li>
# 						<li>
# 							<a href='//www.instagram.com/drugs.com_official/' target='_blank' rel='noopener noreferrer'>
# 								<span class='ddc-sr-only'>Follow Drugs.com on Instagram</span>
# 								<svg class='ddc-icon ddc-icon-instagram' width='24' height='24' viewBox='0 0 24 24' aria-hidden='true' focusable='false' xmlns='http://www.w3.org/2000/svg'><path d='M11.953 3h.094l4.147.121c1.098.124 1.994.382 2.752.964.364.28.69.605.97.969.58.758.84 1.654.963 2.752C21 8.88 21 10.234 21 11.953v.094l-.121 4.147c-.124 1.098-.382 1.994-.964 2.752a5.25 5.25 0 0 1-.969.97c-.758.58-1.654.84-2.752.963C15.12 21 13.766 21 12.047 21h-.094c-1.72 0-3.074 0-4.147-.121-1.098-.124-1.994-.382-2.752-.964a5.25 5.25 0 0 1-.97-.969c-.58-.758-.84-1.654-.963-2.752C3 15.12 3 13.766 3 12.047v-.094l.121-4.147c.124-1.098.382-1.994.964-2.752.28-.364.605-.69.969-.97.758-.58 1.654-.84 2.752-.963C8.88 3 10.234 3 11.953 3zM7.974 4.612c-.964.108-1.553.315-2.007.663-.26.2-.493.432-.692.692-.348.454-.555 1.043-.663 2.007-.11.98-.112 2.25-.112 4.026l.112 4.026c.108.964.315 1.553.663 2.007.2.26.432.493.692.692.454.348 1.043.555 2.007.663.98.11 2.25.112 4.026.112l4.026-.111c.964-.11 1.553-.316 2.007-.664.26-.2.493-.432.692-.692.348-.454.555-1.043.663-2.007.11-.98.112-2.25.112-4.026l-.111-4.026c-.11-.964-.316-1.553-.664-2.007a3.75 3.75 0 0 0-.692-.692c-.454-.348-1.043-.555-2.007-.663-.98-.11-2.25-.112-4.026-.112l-4.026.112zM12 9a3 3 0 1 0 0 6 3 3 0 0 0 0-6zm-4.5 3a4.5 4.5 0 1 1 9 0 4.5 4.5 0 0 1-9 0zm9.375-3.75a1.125 1.125 0 1 0 0-2.25 1.125 1.125 0 0 0 0 2.25z' /></svg>							</a>
# 						</li>
# 						<li>
# 							<a href='//www.youtube.com/user/drugscom' target='_blank' rel='noopener noreferrer'>
# 								<span class='ddc-sr-only'>Follow Drugs.com on YouTube</span>
# 								<svg class='ddc-icon ddc-icon-youtube' width='24' height='24' viewBox='0 0 24 24' aria-hidden='true' focusable='false' xmlns='http://www.w3.org/2000/svg'><path d='M12.25 5c.57 0 2.05.01 3.58.07l.5.01c1.45.06 2.85.16 3.48.32.86.22 1.54.86 1.77 1.68.38 1.33.42 3.96.42 4.5v.18c0 .53-.04 3.16-.42 4.5-.23.81-.9 1.46-1.77 1.68-1.33.34-6.12.39-7.46.4h-.71c-1.33-.01-6.12-.06-7.45-.4a2.45 2.45 0 01-1.77-1.69A22.62 22.62 0 012 11.76v-.19c0-.53.04-3.16.42-4.49.23-.82.9-1.46 1.77-1.68.63-.16 2.03-.26 3.47-.32l.51-.01C9.7 5 11.18 5 11.75 5zm-2.3 3.85v5.63l5.23-2.81-5.23-2.82z' /></svg>							</a>
# 						</li>
# 						<li>
# 							<a href='//www.pinterest.com/drugscom/' target='_blank' rel='noopener noreferrer'>
# 								<span class='ddc-sr-only'>Follow Drugs.com on Pinterest</span>
# 								<svg class='ddc-icon ddc-icon-pinterest' width='24' height='24' viewBox='0 0 24 24' aria-hidden='true' focusable='false' xmlns='http://www.w3.org/2000/svg'><path d='M11.97 3a9 9 0 00-3.29 17.36 8.48 8.48 0 010-2.57l1.06-4.5c-.16-.41-.25-.85-.24-1.29 0-1.25.73-2.19 1.63-2.19a1.14 1.14 0 011.14 1.29c0 .77-.49 1.93-.75 3a1.28 1.28 0 001.35 1.62c1.6 0 2.83-1.69 2.83-4.12a3.55 3.55 0 00-3.77-3.66 3.92 3.92 0 00-4.08 3.9c0 .74.22 1.46.65 2.06.06.07.09.16.06.25l-.25 1.03c-.02.12-.13.2-.3.12-1.13-.53-1.83-2.17-1.83-3.5 0-2.83 2.07-5.44 5.96-5.44 3.13 0 5.57 2.23 5.57 5.2 0 3.1-1.93 5.6-4.69 5.6-.82.02-1.6-.36-2.07-1.03l-.56 2.14a9.98 9.98 0 01-1.12 2.36c.87.25 1.79.38 2.7.37A9.02 9.02 0 0021 12c0-4.97-4.04-9-9.03-9' /></svg>							</a>
# 						</li>
# 					</ul>
# 									<p class='ddc-mg-0 ddc-text-size-small'><a href='/newsletters/'><u>Subscribe to our newsletter</u></a> for the latest medication news, new drug approvals and FDA alerts.</p>
# 			</div>
# 		</nav>
#
# 		<div class='ddc-footer-description ddc-text-color-secondary ddc-text-size-small'>
# 			<strong>Drugs.com</strong> provides accurate and independent information on more than 24,000 prescription drugs, over-the-counter medicines and natural products. This material is provided for educational purposes only and is not intended for medical advice, diagnosis or treatment. Data sources include Micromedex (updated Feb 3, 2026), Cerner Multum&trade; (updated Feb 1, 2026), ASHP (updated Jan 12, 2026) and others.
# 		</div>
#
# 		<div class='ddc-footer-details ddc-flex ddc-flex-gap-5'>
# 			<div class='ddc-footer-badges ddc-flex ddc-flex-justify-center ddc-flex-wrap'>
# 									<a class='ddc-flex-shrink-0' href='//privacy.truste.com/privacy-seal/validation?rid=d18cba4a-afc4-4863-af81-8262bb120271' target='_blank' rel='noopener noreferrer'>
# 						<img src='//privacy-policy.truste.com/privacy-seal/seal?rid=d18cba4a-afc4-4863-af81-8262bb120271' loading='lazy' width='142' height='45' alt='Certified by TRUSTe'>
# 					</a>
# 									<img class='ddc-flex-shrink-0' src='/img/v-20240725/logo/vendor/tag-verified.png' loading='lazy' width='47' height='45' alt='Verified by TAG'>
#
# 				<a class='ddc-flex-shrink-0' href='//aacihealthcare.com/certificates/c173-2022-trust-us/' target='_blank' rel='noopener noreferrer'>
# 					<img src='/img/v-20251028/logo/vendor/trust-mark-logo.png' loading='lazy' width='91' height='45' alt='This website is certified by AACI. Click to verify.'>
# 				</a>
#
# 				<a class='ddc-flex-shrink-0' href='/support/privacy/advertising.html'>
# 					<img src='/img/v-20240725/logo/vendor/adchoices-logomark.png' loading='lazy' width='120' height='45' alt='AdChoices - Ad privacy information'>
# 				</a>
# 			</div>
#
# 			<div class='ddc-footer-copyright ddc-text-color-secondary ddc-text-size-small'>
# 				Copyright &copy; 2000-2026 Drugs.com. <span class='ddc-text-nowrap'>All rights reserved.</span>
# 			</div>
# 		</div>
# 	</div>
# </footer>
# <div class='ddc-social-share'></div>
#
# <script>
# window.SITETIMING = Date.now();
# window.SITECONFIG = {"agent":{"isMobile":false},"user":{"userid":0,"consent":{"reloadPage":false,"region":{"ccpa":false,"gdpr":false},"cookie":{"storeData":"ddc-gdpr-sd","trackAds":"ddc-gdpr-ta","trackContent":"ddc-gdpr-tc","optOut":"ddc-ccpa-oo"}}},"page":{"section":"reviews","subsection":"","doc":"content","delayedScripts":[{"url":"//www.googletagmanager.com/gtm.js?id=GTM-MZ4MM39"},{"url":"//sb.scorecardresearch.com/cs/38584006/beacon.js"}],"pdt":0,"image":{"lazyLoad":{"screens":0.2,"delay":2000}}},"dwLog":{"a":"718","b":"0","c":"10250,568,261,781","d":"117,145,125","e":"120,58","f":2936,"h":0,"i":"default","k":"10250,568,781","l":"","m":"","n":"","o":"","p":0,"q":"reviews","s":[]},"drugs":[{"ddc_id":718,"brand_name_id":0,"mtm_id":"d00012","generic_name":"codeine systemic","name":"codeine"}],"options":{"classifyLists":{"wrapper":"#content","countHtmlItems":false,"numItems":{"short":15,"medium":30,"long":60},"charLimit":{"paragraph":30,"content":350}}},"feedback":{"url":"/comments/codeine/","section":"reviews","doc":"content","referrer":"https://www.drugs.com/codeine.html","css":"/bundle/css/component/component-feedback.min.8680587e.css","target":"#more-resources","triggers":["#more-resources","#footer"]},"modal":[{"type":"account-plan","show":{"selectors":[],"screens":0,"minPageViews":5,"wait":15000},"displayClose":true,"overlayClose":false,"cookie":{"name":"ddc-modal-account-plan","expires":3},"analytics":{"show":{"event":"Content Promo","type":"account-plan","action":"show"},"click":{"event":"Content Promo","type":"account-plan","action":"click"},"close":{"event":"Content Promo","type":"account-plan","action":"close"}},"classList":["ddc-modal-account-plan","ddc-modal-header-icon"],"async":"/api/user/modal/account-plan/?referrer=%2Fcomments%2Fcodeine%2F"},{"type":"compare-drugs","show":{"selectors":[".more-resources",".ddc-footer"],"screens":0,"wait":300000},"displayClose":true,"overlayClose":true,"cookie":{"name":"ddc-modal-compare-treatment","expires":30},"analytics":{"show":{"event":"Content Promo","type":"compare-drugs","action":"show","drug_id":"718-0","drug_name":"codeine"},"click":{"event":"Content Promo","type":"compare-drugs","action":"click","drug_id":"718-0","drug_name":"codeine"},"close":{"event":"Content Promo","type":"compare-drugs","action":"close","drug_id":"718-0","drug_name":"codeine"}},"classList":["ddc-modal-header-icon"],"content":"..."}],"ads":{"section":"reviews","ugc":true,"uvc":null,"isPro":false,"fixable":{"leaderboard":[{"height":250,"duration":7000},{"height":90,"duration":11000},{"height":0,"duration":15000}]},"refresh":{"divIds":["display-ad-1","display-ad-sidebar-"],"maxRefreshCount":5,"minViewArea":75,"minSinceLoad":30000,"minSinceLoadAdx":30000,"minSinceImpression":5000,"minSinceFocus":5000},"interstitial":{"section":"/7146/Interstitial_Ad","ugc":true,"delay":60},"display":{"confiant":false,"mobile":false,"timeout":750,"sectionPrivacy":"/7146/DDC_PRV","targeting":{"p":0,"ugc":1,"rc":0,"d":718,"b":0,"c1":[1832,4292,4066],"c2":[10250,568,261,781],"c2o":[10250,568,781],"dc":[120,58],"ut":[],"mi":1,"rx":1,"pdt":0},"units":[{"id":"display-ad-1","section":"/7146/reviews","sizes":[[728,90]],"sizeMappings":[[[0,0],[]],[[320,300],[[320,50],[300,50]]],[[750,300],[[728,90]]]],"targeting":{"uid":"d-leaderboard-1","location":"leaderboard","mobile":0,"prebid":1,"size":"728x90"},"prebid":1}]},"injection":{"maximum":{"ads":15,"tags":500},"container":"[data-ad-injection]","start":["h1"],"insert":["h2","h3","h4",".ddc-comment"],"blacklist":["blockquote","form","ol","ul","dl","table",".blackboxWarning",".ddc-accordion",".ddc-accordion-wrap",".ddc-box",".ddc-card",".ddc-expand-read-more",".ddc-form-inline",".ddc-grid",".ddc-injection-ignore-inside",".ddc-legend",".ddc-media",".ddc-notification",".ddc-paging",".ddc-reference-list",".responsive-table-wrap",".referenceList"]}},"nativeApp":null,"interaction":{"isDeferredSave":false,"url":"/interaction/list/","param":{"drugList":"drug_list","listId":"interaction_lis ...
# </script>
#
# <script src='//securepubads.g.doubleclick.net/tag/js/gpt.js' async></script>
# <script src='//micro.rubiconproject.com/prebid/dynamic/13482.js' async></script>
# <script src='//cdn.confiant-integrations.net/UEWeDkhzdHOmsrWhvv4ZBOs8vy4/gpt_and_prebid/config.js' async></script>
# <script src='/bundle/6a084fe0/js/module/main-primary.js' type='module'></script>
# <script src='/bundle/6a084fe0/js/module/main-secondary.js' type='module'></script>
# <script src='/bundle/js/polyfill.min.d0f60cac.js' nomodule defer></script>
# <script src='/bundle/js/polyfill/promise/polyfill.min.61fc9c0d.js' nomodule defer></script>
# <script src='/bundle/js/polyfill/fetch/fetch.umd.min.fae84870.js' nomodule defer></script>
# <script src='/bundle/js/polyfill/intersection-observer/IntersectionObserver.min.48c80c7c.js' nomodule defer></script>
# <script src='/bundle/js/rollup.min.6a084fe0.js' nomodule defer></script>
# <script>
# window.dataLayer = window.dataLayer || [];
# window.dataLayer.push({'gtm.start': new Date().getTime(), event: 'gtm.js'});
# window.dataLayer.push({"event":"pageview","drug_name":"codeine","drug_id":"718-0","ddc_id":"718","condition_ids":";10250;568;261;781;","zone_ids":";1832;4292;4066;","user_signed_in":"No","user_ilink":"No","page_index_status":"index/follow","page_orphan":"No","page_traffic_op":"No","content_type":"Drug","content_section":"User Reviews","content_sub_section":"User Reviews","content_audience":"Consumer","content_language":"English","content_size":"Long Page","content_ugc":"Yes","app_source":"Web","ads_pro":"No","ads_pdt_condition":"No","ads_pdt_status":"featured_priority"});
# </script>
# <script>
# window._comscore = window._comscore || [];
# window._comscore.push({c1: '2', c2: '38584006', cs_ucfr: '', options: {enableFirstPartyCookie: true, bypassUserConsentRequirementFor1PCookie: true}});
# </script>
#
# <!-- 2026-02-07T07:46:42+00:00 -->
#
# <noscript><img src="https://www.drugs.com/akam/13/pixel_70ea034e?a=dD1kYjdlN2JjOWNmODVjYmRiNGJjOWNmM2MxYWQ5NjZkMjkxNmY5Njk5JmpzPW9mZg==" style="visibility: hidden; position: absolute; left: -999px; top: -999px;" /></noscript></body>
# </html>
